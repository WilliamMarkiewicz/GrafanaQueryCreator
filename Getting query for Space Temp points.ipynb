# %%
import pandas as pd

# Read the CSV file into a pandas DataFrame
file_path = r'YOUR FILE PATH HEREdf = pd.read_csv(file_path)

# Filter rows where "Space Temp" is included in the "point" column, but exclude "Space Temp Setpoint"
filtered_df = df[df['point'].str.contains('Space Temp') & (df['point'] != 'Space Temp Setpoint')]

# Extract the entries from the "topic" column
space_temp_topics = filtered_df['topic'].tolist()

# Construct the Grafana query
grafana_query = 'from(bucket: "ce_bms_as")\n' \
                '  |> range(start: v.timeRangeStart, stop: v.timeRangeStop)\n' \
                '  |> filter(fn: (r) => r["_measurement"] == "mqtt_consumer")\n' \
                '  |> filter(fn: (r) =>\n'

# Add each topic as a separate condition in the query
for i, topic in enumerate(space_temp_topics):
    if i != 0:
        grafana_query += '    or '
    grafana_query += f'r["opsbmsas-topics"] == "{topic}"\n'

# Add the closing parentheses and the rest of the query
grafana_query += '  )\n' \
                 '  |> filter(fn: (r) => exists r["_value"])\n' \
                 '  |> aggregateWindow(every: v.windowPeriod, fn: mean, createEmpty: false)\n' \
                 '  |> yield(name: "mean")'

print(grafana_query)
# Out:
# from(bucket: "ce_bms_as")
#   |> range(start: v.timeRangeStart, stop: v.timeRangeStop)
#   |> filter(fn: (r) => r["_measurement"] == "mqtt_consumer")
#   |> filter(fn: (r) =>
# r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE01-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/VAV/TE01_LB1_RPC_01/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE01-XX-MCC-001/BACnet Interface/IP Network/TE01_LB1_RPC_01/Application/Monitoring/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE01-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/VAV/TE01_RSH_RPC_01/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE01-XX-MCC-001/BACnet Interface/IP Network/TE01_RSH_RPC_01/Application/Monitoring/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE01-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/VAV/TE01_SS1_RPC_01/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE01-XX-MCC-001/BACnet Interface/IP Network/TE01_SS1_RPC_01/Application/Monitoring/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE01-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/VAV/TE01_SS2_RPC_01/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE01-XX-MCC-001/BACnet Interface/IP Network/TE01_SS2_RPC_01/Application/Monitoring/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/VAV/TE02_Off_RPC_01/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/IP Network/TE02_Off_RPC_01/Application/Monitoring/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/VAV/TE02_Off_RPC_02/Space Temp 6b/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/VAV/TE02_Off_RPC_02/Space Temp 6c/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/IP Network/TE02_Off_RPC_02/Application/Monitoring/Space Temp 6B/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/IP Network/TE02_Off_RPC_02/Application/Monitoring/Space Temp 6C/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/VAV/TE02_Off_RPC_03/Space Temp 19a/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/VAV/TE02_Off_RPC_03/Space Temp 19b/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/IP Network/TE02_Off_RPC_03/Application/Monitoring/Space Temp 19a/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/IP Network/TE02_Off_RPC_03/Application/Monitoring/Space Temp 19b/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/VAV/TE02_Off_RPC_04/Space Temp  2_13/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/VAV/TE02_Off_RPC_04/Space Temp 2_14/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/IP Network/TE02_Off_RPC_04/Application/Monitoring/Space Temp 2_13/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/IP Network/TE02_Off_RPC_04/Application/Monitoring/Space Temp 2_14/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/VAV/TE02_QCR_RPC_01/Space Temp 2-16/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/VAV/TE02_QCR_RPC_01/Space Temp 2-18/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/IP Network/TE02_QCR_RPC_01/Application/Monitoring/Space Temp 2_16/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/IP Network/TE02_QCR_RPC_01/Application/Monitoring/Space Temp 2_18/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/VAV/TE02_TS2_RPC_01/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/IP Network/TE02_TS2_RPC_01/Application/Monitoring/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/VAV/TE02_TS3_RPC_01/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/IP Network/TE02_TS3_RPC_01/Application/Monitoring/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/VAV/TE02_TS4_RPC_01/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/IP Network/TE02_TS4_RPC_01/Application/Monitoring/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/VAV/TE02_WRK3_RPC_01/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/IP Network/TE02_WRK3_RPC_01/Application/Monitoring/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/VAV/TE02_WRK3_RPC_02/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/IP Network/TE02_WRK3_RPC_02/Application/Monitoring/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/VAV/TW02_Off_RPC_01/Space Temp 201/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/VAV/TW02_Off_RPC_01/Space Temp 201A/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/IP Network/TW02_Off_RPC_01/Application/Monitoring/Space Temp 201/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/IP Network/TW02_Off_RPC_01/Application/Monitoring/Space Temp 201a/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/VAV/TW02_Off_RPC_02/Space Temp 2_03A/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/VAV/TW02_Off_RPC_02/Space Temp 2_03B/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/IP Network/TW02_Off_RPC_02/Application/Monitoring/Space Temp 2_03a/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/IP Network/TW02_Off_RPC_02/Application/Monitoring/Space Temp 2_03b/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/VAV/TW02_Off_RPC_03/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/IP Network/TW02_Off_RPC_03/Application/Monitoring/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/VAV/TW02_WRK1_RPC_01/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/IP Network/TW02_WRK1_RPC_01/Application/Monitoring/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/VAV/TW02_WRK2_RPC_01/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/IP Network/TW02_WRK2_RPC_01/Application/Monitoring/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/VAV/TW02_WRK2_RPC_02/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/IP Network/TW02_WRK2_RPC_02/Application/Monitoring/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/VAV/TW02_WRK3_RPC_01/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/IP Network/TW02_WRK3_RPC_01/Application/Monitoring/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/VAV/TW02_WRK3_RPC_02/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TE02-XX-MCC-001/BACnet Interface/IP Network/TW02_WRK3_RPC_02/Application/Monitoring/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TW01-XX-MCC-002/BACnet Interface/Application/Energy Monitoring/VAV/TW00_MEGR1_RPC_01/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TW01-XX-MCC-002/BACnet Interface/IP Network/TW00_MEGR1_RPC_01/Application/Monitoring/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TW01-XX-MCC-002/BACnet Interface/Application/Energy Monitoring/VAV/TW01_CE1_RPC_01/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TW01-XX-MCC-002/BACnet Interface/IP Network/TW01_CE1_RPC_01/Application/Monitoring/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TW01-XX-MCC-002/BACnet Interface/Application/Energy Monitoring/VAV/TW01_CE1_RPC_02/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TW01-XX-MCC-002/BACnet Interface/IP Network/TW01_CE1_RPC_02/Application/Monitoring/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TW01-XX-MCC-002/BACnet Interface/Application/Energy Monitoring/VAV/TW01_LBR_RPC_01/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TW01-XX-MCC-002/BACnet Interface/IP Network/TW01_LBR_RPC_01/Application/Monitoring/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TW01-XX-MCC-002/BACnet Interface/Application/Energy Monitoring/VAV/TW01_LBR_RPC_02/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TW01-XX-MCC-002/BACnet Interface/IP Network/TW01_LBR_RPC_02/Application/Monitoring/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TW01-XX-MCC-002/BACnet Interface/Application/Energy Monitoring/VAV/TW01_TS1_RPC_01/Space Temp/Value"
#     or r["opsbmsas-topics"] == "UCL/OPSEBOAS/PSW TW01-XX-MCC-002/BACnet Interface/IP Network/TW01_TS1_RPC_01/Application/Monitoring/Space Temp/Value"
#   )
#   |> filter(fn: (r) => exists r["_value"])
#   |> aggregateWindow(every: v.windowPeriod, fn: mean, createEmpty: false)
#   |> yield(name: "mean")

# %%
import pandas as pd
import json
import pyperclip

# Read the CSV file into a pandas DataFrame
file_path = r'C:\Users\ucbqwdm.AD\OneDrive - University College London\Documents\PhD\Digital Twin Project\One Pool Street\BMS Data Harvesting\EBOAS Grafana Dashboarding\MQTT_Points_Mapping.csv'
df = pd.read_csv(file_path)

# Construct JSON overrides for each topic
overrides = []

for _, row in df.iterrows():
    # Extract relevant column entries
    level = str(row['level']) if not pd.isna(row['level']) else ''
    space = str(row['space']) if not pd.isna(row['space']) else ''
    zone = str(row['zone']) if not pd.isna(row['zone']) else ''
    topic = row['topic']
    
    # Format the display name
    display_name = f'{level}-{space}-{zone}'
    
    # Construct JSON override
    override = {
        "matcher": {
            "id": "byName",
            "options": f"value {{host=\"ce-data\", opsbmsas-topics=\"{topic}\"}}"
        },
        "properties": [
            {
                "id": "displayName",
                "value": display_name
            }
        ]
    }
    
    overrides.append(override)

# Convert overrides to JSON string
overrides_json = [json.dumps(override, indent=2) for override in overrides]

# Concatenate JSON strings
json_output = ',\n'.join(overrides_json)

# Copy JSON output to clipboard
pyperclip.copy(json_output)

# Print the generated JSON overrides
for override in overrides_json:
    print(override)
# Out:
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_GDI_RPC_01/Application/Points/VAV1/SupVavFlowControlSp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G19-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_GDI_RPC_01/Application/Points/VAV2/SupVavFlowControlSp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G19-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_GDI_RPC_01/Application/Monitoring/VAV1 Flow/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G19-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_GDI_RPC_01/Application/Monitoring/VAV1 Flow Sp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G19-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_GDI_RPC_01/Application/Monitoring/VAV2 Flow/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G19-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_GDI_RPC_01/Application/Monitoring/VAV2 Flow Sp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G19-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_GDI_RPC_01/IO Resources/Sensor Bus/Wall Sensor/CO2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G19-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_GDI_RPC_01/Application/Monitoring/Space CO2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G19-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_GDI_RPC_01/Application/Variables/SpaceCo2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G19-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_SLD_RPC_01/Application/Points/VAV1/SupVavFlowControlSp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G20-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_SLD_RPC_01/Application/Points/VAV2/SupVavFlowControlSp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G20-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_SLD_RPC_01/Application/Points/VAV3/SupVavFlowControlSp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G20-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_SLD_RPC_01/Application/Monitoring/VAV1 Flow/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G20-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_SLD_RPC_01/Application/Monitoring/VAV1 Flow Sp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G20-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_SLD_RPC_01/Application/Monitoring/VAV2 Flow/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G20-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_SLD_RPC_01/Application/Monitoring/VAV2 Flow Sp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G20-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_SLD_RPC_01/Application/Monitoring/VAV3 Flow/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G20-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_SLD_RPC_01/Application/Monitoring/VAV3 Flow Sp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G20-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_SLD_RPC_01/Application/Monitoring/Space CO2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G20-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_SLD_RPC_02/Application/Points/VAV1/SupVavFlowControlSp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G20-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_SLD_RPC_02/Application/Points/VAV2/SupVavFlowControlSp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G20-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_SLD_RPC_02/Application/Points/VAV3/SupVavFlowControlSp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G20-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_SLD_RPC_02/Application/Monitoring/VAV1 Flow/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G20-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_SLD_RPC_02/Application/Monitoring/VAV1 Flow Sp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G20-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_SLD_RPC_02/Application/Monitoring/VAV2 Flow/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G20-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_SLD_RPC_02/Application/Monitoring/VAV2 Flow Sp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G20-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_SLD_RPC_02/Application/Monitoring/VAV3 Flow Sp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G20-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_SLD_RPC_02/IO Resources/Sensor Bus/Wall Sensor/CO2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G20-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_SLD_RPC_02/Application/Monitoring/Space CO2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G20-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TE00_SLD_RPC_02/Application/Network Variables/xCo2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L00-G20-"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-CE-001/BACnet Interface/IP Network/TW00_CU_FCU_002/IO Resources/Sensor Bus/Wall Sensor/CO2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Fans/EF001En/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Fans/EF001Speed/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Fans/EF002En/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Fans/EF002Speed/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Fans/SF001En/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Fans/SF001Speed/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Fans/SF002En/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Fans/SF002Speed/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Various/BMSResetCMD/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-MCC-001/Network Variables/OAH/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW 0000-XX-MCC-001/Network Variables/OAT/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-CE-001/Network Variables/OAH/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Heat Meters/003-Secondary LTHW Student West HIUs/Energy/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Heat Meters/003-Secondary LTHW Student West HIUs/Flow/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Heat Meters/003-Secondary LTHW Student West HIUs/Inlet Temp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Heat Meters/003-Secondary LTHW Student West HIUs/Outlet Temp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Heat Meters/003-Secondary LTHW Student West HIUs/Power/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Heat Meters/004-Secondary LTHW Student East HIUs/Energy/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Heat Meters/004-Secondary LTHW Student East HIUs/Flow/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Heat Meters/004-Secondary LTHW Student East HIUs/Inlet Temp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Heat Meters/004-Secondary LTHW Student East HIUs/Outlet Temp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Heat Meters/004-Secondary LTHW Student East HIUs/Power/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Heat Meters/005-Primary CHW/Energy/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Heat Meters/005-Primary CHW/Flow/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Heat Meters/005-Primary CHW/Inlet Temp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Heat Meters/005-Primary CHW/Outlet Temp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Heat Meters/005-Primary CHW/Power/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Heat Meters/006-Secondary West Podium CHW/Energy/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Heat Meters/006-Secondary West Podium CHW/Flow/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Heat Meters/006-Secondary West Podium CHW/Inlet Temp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Heat Meters/006-Secondary West Podium CHW/Outlet Temp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Heat Meters/006-Secondary West Podium CHW/Power/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Heat Meters/007-Secondary East Podium CHW/Energy/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Heat Meters/007-Secondary East Podium CHW/Flow/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Heat Meters/007-Secondary East Podium CHW/Inlet Temp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Heat Meters/007-Secondary East Podium CHW/Outlet Temp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/Heat Meters/007-Secondary East Podium CHW/Power/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-003-Secondary LTHW Student West HIUs/Modbus Signals/Table 1/256 Heat Enegy E1/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-003-Secondary LTHW Student West HIUs/Modbus Signals/Table 1/258 Actual Flow/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-003-Secondary LTHW Student West HIUs/Modbus Signals/Table 1/260 Volume V1/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-003-Secondary LTHW Student West HIUs/Modbus Signals/Table 1/262 Actual Power/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-003-Secondary LTHW Student West HIUs/Modbus Signals/Table 1/264 Inlet Temperature T1/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-003-Secondary LTHW Student West HIUs/Modbus Signals/Table 1/266 Outlet Temperature T2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-003-Secondary LTHW Student West HIUs/Modbus Signals/Table 1/268 Pulse Input A/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-003-Secondary LTHW Student West HIUs/Modbus Signals/Table 1/270 Pulse Input B/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-003-Secondary LTHW Student West HIUs/Modbus Signals/Table 8/302 Cooling Energy E3/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-003-Secondary LTHW Student West HIUs/Modbus Signals/Table 12/318 Max Power/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-003-Secondary LTHW Student West HIUs/Modbus Signals/Table 12/320 Tarif 2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-003-Secondary LTHW Student West HIUs/Modbus Signals/Table 12/322 Tarif 3/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-003-Secondary LTHW Student West HIUs/Modbus Signals/Table 12/324 Tarif Limit 2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-003-Secondary LTHW Student West HIUs/Modbus Signals/Table 12/326 Tarif Limit 3/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-004-Secondary LTHW Student East HIUs/Modbus Signals/Table 1/256 Heat Enegy E1/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-004-Secondary LTHW Student East HIUs/Modbus Signals/Table 1/258 Actual Flow/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-004-Secondary LTHW Student East HIUs/Modbus Signals/Table 1/260 Volume V1/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-004-Secondary LTHW Student East HIUs/Modbus Signals/Table 1/262 Actual Power/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-004-Secondary LTHW Student East HIUs/Modbus Signals/Table 1/264 Inlet Temperature T1/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-004-Secondary LTHW Student East HIUs/Modbus Signals/Table 1/266 Outlet Temperature T2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-004-Secondary LTHW Student East HIUs/Modbus Signals/Table 1/268 Pulse Input A/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-004-Secondary LTHW Student East HIUs/Modbus Signals/Table 1/270 Pulse Input B/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-004-Secondary LTHW Student East HIUs/Modbus Signals/Table 8/302 Cooling Energy E3/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-004-Secondary LTHW Student East HIUs/Modbus Signals/Table 12/318 Max Power/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-004-Secondary LTHW Student East HIUs/Modbus Signals/Table 12/320 Tarif 2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-004-Secondary LTHW Student East HIUs/Modbus Signals/Table 12/322 Tarif 3/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-004-Secondary LTHW Student East HIUs/Modbus Signals/Table 12/324 Tarif Limit 2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-004-Secondary LTHW Student East HIUs/Modbus Signals/Table 12/326 Tarif Limit 3/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-005-Primary CHW/Modbus Signals/Table 1/256 Heat Enegy E1/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-005-Primary CHW/Modbus Signals/Table 1/258 Actual Flow/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-005-Primary CHW/Modbus Signals/Table 1/260 Volume V1/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-005-Primary CHW/Modbus Signals/Table 1/262 Actual Power/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-005-Primary CHW/Modbus Signals/Table 1/264 Inlet Temperature T1/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-005-Primary CHW/Modbus Signals/Table 1/266 Outlet Temperature T2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-005-Primary CHW/Modbus Signals/Table 1/268 Pulse Input A/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-005-Primary CHW/Modbus Signals/Table 1/270 Pulse Input B/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-005-Primary CHW/Modbus Signals/Table 8/302 Cooling Energy E3/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-005-Primary CHW/Modbus Signals/Table 12/318 Max Power/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-005-Primary CHW/Modbus Signals/Table 12/320 Tarif 2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-005-Primary CHW/Modbus Signals/Table 12/322 Tarif 3/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-005-Primary CHW/Modbus Signals/Table 12/324 Tarif Limit 2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-005-Primary CHW/Modbus Signals/Table 12/326 Tarif Limit 3/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-006-Secondary West Podium CHW/Modbus Signals/Table 1/256 Heat Enegy E1/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-006-Secondary West Podium CHW/Modbus Signals/Table 1/258 Actual Flow/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-006-Secondary West Podium CHW/Modbus Signals/Table 1/260 Volume V1/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-006-Secondary West Podium CHW/Modbus Signals/Table 1/262 Actual Power/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-006-Secondary West Podium CHW/Modbus Signals/Table 1/264 Inlet Temperature T1/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-006-Secondary West Podium CHW/Modbus Signals/Table 1/266 Outlet Temperature T2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-006-Secondary West Podium CHW/Modbus Signals/Table 1/268 Pulse Input A/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-006-Secondary West Podium CHW/Modbus Signals/Table 1/270 Pulse Input B/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-006-Secondary West Podium CHW/Modbus Signals/Table 8/302 Cooling Energy E3/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-006-Secondary West Podium CHW/Modbus Signals/Table 12/318 Max Power/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-006-Secondary West Podium CHW/Modbus Signals/Table 12/320 Tarif 2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-006-Secondary West Podium CHW/Modbus Signals/Table 12/322 Tarif 3/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-006-Secondary West Podium CHW/Modbus Signals/Table 12/324 Tarif Limit 2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-006-Secondary West Podium CHW/Modbus Signals/Table 12/326 Tarif Limit 3/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-007-Secondary East Podium CHW/Modbus Signals/Table 1/256 Heat Enegy E1/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-007-Secondary East Podium CHW/Modbus Signals/Table 1/258 Actual Flow/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-007-Secondary East Podium CHW/Modbus Signals/Table 1/260 Volume V1/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-007-Secondary East Podium CHW/Modbus Signals/Table 1/262 Actual Power/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-007-Secondary East Podium CHW/Modbus Signals/Table 1/264 Inlet Temperature T1/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-007-Secondary East Podium CHW/Modbus Signals/Table 1/266 Outlet Temperature T2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-007-Secondary East Podium CHW/Modbus Signals/Table 1/268 Pulse Input A/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-007-Secondary East Podium CHW/Modbus Signals/Table 1/270 Pulse Input B/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-007-Secondary East Podium CHW/Modbus Signals/Table 8/302 Cooling Energy E3/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-007-Secondary East Podium CHW/Modbus Signals/Table 12/318 Max Power/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-007-Secondary East Podium CHW/Modbus Signals/Table 12/320 Tarif 2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-007-Secondary East Podium CHW/Modbus Signals/Table 12/322 Tarif 3/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-007-Secondary East Podium CHW/Modbus Signals/Table 12/324 Tarif Limit 2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/Modbus Master Network/B000-XX-HM-007-Secondary East Podium CHW/Modbus Signals/Table 12/326 Tarif Limit 3/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/CHW/DiffPressSP/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/CHW/P013En/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/CHW/P013Speed/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/CHW/P014En/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/CHW/P014Speed/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/CHW/P015En/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/CHW/P015Speed/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/CHW/P016En/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-001/BACnet Interface/Application/Energy Monitoring/CHW/P016Speed/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-002/BACnet Interface/Application/Energy Monitoring/Heat Meters/001-Secondary LTHW Podium/Power/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-002/BACnet Interface/Application/Energy Monitoring/LTHW/P007Speed/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW B000-XX-MCC-002/BACnet Interface/Application/Energy Monitoring/LTHW/STHRUAveragePress/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
# ...
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/Modbus Master Network/TW01-XX-HM-004/Modbus Signals/Table 1/266 Outlet Temperature T2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/Modbus Master Network/TW01-XX-HM-004/Modbus Signals/Table 1/268 Pulse Input A/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/Modbus Master Network/TW01-XX-HM-004/Modbus Signals/Table 1/270 Pulse Input B/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/Modbus Master Network/TW01-XX-HM-004/Modbus Signals/Table 2/272 Unit Heat Energy E1/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/Modbus Master Network/TW01-XX-HM-004/Modbus Signals/Table 2/273 Unit Actual Flow/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/Modbus Master Network/TW01-XX-HM-004/Modbus Signals/Table 2/274 Unit Volume V1/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/Modbus Master Network/TW01-XX-HM-004/Modbus Signals/Table 2/275 Unit Actual Power/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/Modbus Master Network/TW01-XX-HM-004/Modbus Signals/Table 8/302 Cooling Energy E3/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/Modbus Master Network/TW01-XX-HM-004/Modbus Signals/Table 12/318 Max Power/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/Modbus Master Network/TW01-XX-HM-004/Modbus Signals/Table 12/320 Tarif 2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/Modbus Master Network/TW01-XX-HM-004/Modbus Signals/Table 12/322 Tarif 3/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/Modbus Master Network/TW01-XX-HM-004/Modbus Signals/Table 12/324 Tarif Limit 2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/Modbus Master Network/TW01-XX-HM-004/Modbus Signals/Table 12/326 Tarif Limit 3/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/Modbus Master Network/TW01-XX-HM-004/Modbus Signals/Table 13/328 Meter Type/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/Modbus Master Network/TW01-XX-HM-004/Modbus Signals/Table 13/330 Meter Number/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/Modbus Master Network/TW01-XX-HM-004/Modbus Signals/Table 13/332 Serial Number/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/Modbus Master Network/TW01-XX-HM-004/Modbus Signals/Table 13/334 Program Number/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/Modbus Master Network/TW01-XX-HM-004/Modbus Signals/Table 13/336 Config Number 1/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/Modbus Master Network/TW01-XX-HM-004/Modbus Signals/Table 13/338 Config Number 2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/Modbus Master Network/TW01-XX-HM-004/Modbus Signals/Table 13/340 Hour Counter/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/BACnet Interface/Application/Energy Monitoring/Heat Meters/TW01-XX-HM-004/Energy/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/BACnet Interface/Application/Energy Monitoring/Heat Meters/TW01-XX-HM-004/Flow/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/BACnet Interface/Application/Energy Monitoring/Heat Meters/TW01-XX-HM-004/Inlet Temp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/BACnet Interface/Application/Energy Monitoring/Heat Meters/TW01-XX-HM-004/Outlet Temp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/BACnet Interface/Application/Energy Monitoring/Heat Meters/TW01-XX-HM-004/Power/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/BACnet Interface/Application/Energy Monitoring/Various/BMSResetCmd/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/Network Variables/OAH/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/Network Variables/OAT/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/BACnet Interface/Application/Energy Monitoring/Various/ProjIsoDmpr1/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/BACnet Interface/Application/Energy Monitoring/Various/ProjIsoDmpr2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/BACnet Interface/Application/Energy Monitoring/Various/ProjIsoDmpr3/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/BACnet Interface/Application/Energy Monitoring/Various/ProjRmExtFanEn/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/BACnet Interface/Application/Energy Monitoring/Various/ProjRmExtFanSpd/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/BACnet Interface/Application/Energy Monitoring/Water Meters/TW00WM001WtrMtr/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW01-XX-MCC-002/BACnet Interface/Application/Energy Monitoring/Water Meters/TW00WM003WtrMtr/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW02-XX-MCC-001/Network Variables/OAH/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW20-XX-CE-001/Modbus TCP Gateway/L19-C2-HIU/DhwsTemp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L19--C2"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW20-XX-CE-001/Modbus TCP Gateway/L4-C2-HIU/DhwsTemp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L04--C2"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW20-XX-CE-001/Modbus TCP Gateway/L5-C1-HIU/DhwsTemp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L05--C1"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW20-XX-CE-001/Modbus TCP Gateway/L6-C2-HIU/DhwsTemp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L06--C2"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW20-XX-CE-001/Modbus TCP Gateway/L7-C1-HIU/DhwsTemp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L07--C1"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW20-XX-CE-001/Residentail Apartments/TW04-01-CE-001/HIUs/C2/Variables/DHW Temp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L04--C2"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW20-XX-CE-001/BACnet Interface/Application/Energy Monitoring/Residential Apartments/TW04-01-CE-001/DHW Temp_C2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L04--C2"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW20-XX-CE-001/Residentail Apartments/TW05-01-CE-001/HIUs/C1/Variables/DHW Temp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L05--C1"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW20-XX-CE-001/BACnet Interface/Application/Energy Monitoring/Residential Apartments/TW05-01-CE-001/DHW Temp_C1/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L05--C1"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW20-XX-CE-001/Residentail Apartments/TW06-01-CE-001/HIUs/C2/Variables/DHW Temp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L06--C2"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW20-XX-CE-001/BACnet Interface/Application/Energy Monitoring/Residential Apartments/TW06-01-CE-001/DHW Temp_C2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L06--C2"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW20-XX-CE-001/Residentail Apartments/TW07-01-CE-001/HIUs/C1/Variables/DHW Temp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L07--C1"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW20-XX-CE-001/BACnet Interface/Application/Energy Monitoring/Residential Apartments/TW07-01-CE-001/DHW Temp_C1/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L07--C1"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW20-XX-CE-001/Residentail Apartments/TW19-01-CE-001/HIUs/C2/Variables/DHW Temp/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L19--C2"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW20-XX-CE-001/BACnet Interface/Application/Energy Monitoring/Residential Apartments/TW19-01-CE-001/DHW Temp_C2/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "L19--C2"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW20-XX-CE-001/Programs/Network Variables/Differential Pressure Sensor/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
# {
#   "matcher": {
#     "id": "byName",
#     "options": "value {host=\"ce-data\", opsbmsas-topics=\"UCL/OPSEBOAS/PSW TW20-XX-CE-001/Programs/Network Variables/OAH/Value\"}"
#   },
#   "properties": [
#     {
#       "id": "displayName",
#       "value": "--"
#     }
#   ]
# }
